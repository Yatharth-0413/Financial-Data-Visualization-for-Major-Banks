# %% [markdown]
# <a href="https://colab.research.google.com/github/Yatharth-0413/Financial-Data-Visualization-for-Major-Banks/blob/main/Financial_Data_Visualization_for_Major_Banks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Financial Data Visualization for **Major** **Banks**

# %% [markdown]
# Analyzing Bank Stocks Performance during **Financial Crisis** using Python
# Technologies Used: Python, pandas, cufflinks, Plotly, Google Colab

# %% [markdown]
# Bank Stocks Analysis: This project focuses on analyzing the stock
#
# 1.   performance of major banks (***Bank of America, CitiGroup, Goldman Sachs, JPMorgan Chase, Morgan Stanley, Wells Fargo***) from January 1, 2006, to January 1, 2016.
# 2.   The analysis includes fetching stock data, examining closing prices, calculating returns, visualizing data, and performing technical analysis. This project provides insights into the financial crisis and its impact on bank stocks, using various data visualization techniques and statistical measures.

# %% [markdown]
# Step 1: Install Necessary Libraries
#
# Step 2: Import Required Libraries
#
# Step 3: Define Start and End Dates
#
# Step 4: Define Stock Tickers
#
# Step 5: Fetch Stock Data
#
# Step 6: Create Separate DataFrames for Each Bank
#
# Step 7: Alphabetize Ticker Symbols
#
# Step 8: Concatenate DataFrames
#
# Step 9: Set Column Name Levels
#
# Step 10: PERFORM EDA:

# %%
# !pip install pandas-datareader

# %%
from pandas_datareader import data, wb
import pandas_datareader.data as web
import pandas as pd
import numpy as np
import datetime
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
startDate = datetime.datetime(2006, 1, 1)
endDate = datetime.datetime(2016, 1, 1)

# %%
# Define the stock tickers and time period
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']
data = yf.download(tickers, start=startDate, end=endDate)

# Set each bank to be a separate dataframe
bank_dfs = {ticker: data.xs(ticker, level=1, axis=1) for ticker in tickers}

# Example to access individual dataframes
BAC = bank_dfs['BAC']
C = bank_dfs['C']
GS = bank_dfs['GS']
JPM = bank_dfs['JPM']
MS = bank_dfs['MS']
WFC = bank_dfs['WFC']
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
data
# Out:
# Price       Adj Close                                                \
# Ticker            BAC           C          GS        JPM         MS
# Date
# 2006-01-03  31.750557  332.317047   96.809410  24.652082  32.955105
# 2006-01-04  31.413363  326.181854   95.472229  24.509798  32.977699
# 2006-01-05  31.453831  327.799805   95.434685  24.584042  33.068134
# 2006-01-06  31.406610  327.799805   96.786896  24.757248  33.102043
# 2006-01-09  31.426847  326.249207   97.951286  25.159351  33.452461
# ...               ...         ...         ...        ...        ...
# 2015-12-24  14.364413   41.217289  153.395142  52.499428  25.581106
# 2015-12-28  14.247965   40.959240  152.680557  52.326004  25.336948
# 2015-12-29  14.372731   41.428421  154.286224  52.869926  25.636236
# 2015-12-30  14.181425   40.896683  153.008423  52.491550  25.384197
# 2015-12-31  13.998443   40.466595  151.512054  52.050117  25.053415
#
# Price                      Close                                     ...  \
# ...

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC],axis=1,keys=tickers)
bank_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2006-01-03 to 2015-12-31
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (BAC, Adj Close)  2517 non-null   float64
#  1   (BAC, Close)      2517 non-null   float64
#  2   (BAC, High)       2517 non-null   float64
#  3   (BAC, Low)        2517 non-null   float64
#  4   (BAC, Open)       2517 non-null   float64
#  5   (BAC, Volume)     2517 non-null   int64
#  6   (C, Adj Close)    2517 non-null   float64
#  7   (C, Close)        2517 non-null   float64
#  8   (C, High)         2517 non-null   float64
#  9   (C, Low)          2517 non-null   float64
#  10  (C, Open)         2517 non-null   float64
#  11  (C, Volume)       2517 non-null   int64
#  12  (GS, Adj Close)   2517 non-null   float64
#  13  (GS, Close)       2517 non-null   float64
#  14  (GS, High)        2517 non-null   float64
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info   Adj Close      Close       High        Low       Open    Volume
# Date
# 2006-01-03   31.750557  47.080002  47.180000  46.150002  46.919998  16296700
# 2006-01-04   31.413363  46.580002  47.240002  46.450001  47.000000  17757900
# 2006-01-05   31.453831  46.639999  46.830002  46.320000  46.580002  14970700
# 2006-01-06   31.406610  46.570000  46.910000  46.349998  46.799999  12599800
# 2006-01-09   31.426847  46.599998  46.970001  46.360001  46.720001  15619400
#
# Bank Ticker           C                                      ...         MS  \
# Stock Info    Adj Close       Close        High         Low  ...       High
# Date                                                         ...
# 2006-01-03   332.317047  492.899994  493.799988  481.100006  ...  58.490002
# 2006-01-04   326.181854  483.799988  491.000000  483.500000  ...  59.279999
# ...

# %%
type(bank_stocks)
# Out:
# pandas.core.frame.DataFrame

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
# What is the max Open price for each bank's stock throughout the time period?
bank_stocks.xs(key='Open',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     55.040001
# C      566.000000
# GS     243.550003
# JPM     70.190002
# MS      90.769997
# WFC     58.730000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick + ' Return'] = bank_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
import seaborn as sns
sns.pairplot(returns)

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std() # Very similar risk profiles, but Morgan Stanley or BofA
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
sns.displot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],color='green',bins=100)

# %%
returns.loc['2015-01-01':'2015-01-20']
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2015-01-02    0.000559  0.002772   0.002992   -0.001438  -0.002320   -0.002189
# 2015-01-05   -0.029050 -0.031515  -0.031223   -0.031045  -0.031258   -0.027422
# 2015-01-06   -0.029919 -0.035205  -0.020229   -0.025929  -0.028800   -0.020865
# 2015-01-07    0.004745  0.009270   0.014903    0.001526   0.014278    0.005951
# 2015-01-08    0.020661  0.015048   0.015965    0.022346   0.014889    0.022137
# 2015-01-09   -0.017930 -0.022333  -0.015347   -0.017387  -0.016271   -0.016430
# 2015-01-12   -0.017668 -0.007877  -0.012170   -0.008595  -0.013829   -0.011959
# 2015-01-13   -0.013789 -0.007146  -0.000757    0.000170  -0.009348   -0.003842
# 2015-01-14   -0.024924 -0.019392  -0.025415   -0.034500  -0.022759   -0.011572
# 2015-01-15   -0.052369 -0.037105  -0.009654   -0.032037  -0.017893   -0.010341
# 2015-01-16    0.011842  0.008046  -0.007059    0.017094   0.008965    0.018139
# ...

# %%
sns.displot(returns.loc['2008-01-01':'2008-01-31']['C Return'],bins=100,color='red')

# %%
# !pip install cufflinks
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.0 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12,4),label=tick)
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>                            <div id="dca4bdc0-872c-434f-9482-b5fdafc5a120" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
# Out:
# <Axes: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
BAC['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# <div>                            <div id="b891539b-95fe-411b-afd8-7d7195c76011" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
